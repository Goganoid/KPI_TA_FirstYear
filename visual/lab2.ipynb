# %%
import numpy as np
import pandas as pd
from IPython.display import Markdown as md
from IPython.display import display
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as tkr

# %%
def numfmt(x, pos): # your custom formatter function: divide by 100.0
    s = '{}k'.format(x / 1000.0)
    return s

fig, ax = plt.subplots() 
plt.grid()
sizes = [i for i in range(15,20*250,250)]
experimental = [1628284,1533956,10349408,5824405,10426051,15810500,18421905,24540005,32056221,41190510,50692454,63470283,76859723,79740002,101516712,117592189,153065332,150191115,181070393,190579462]
ax.plot(sizes,experimental,label='Реальна складність')
ax.plot(sizes,np.linspace(np.sqrt(1700000),np.sqrt(200000000),20)**2,'--r',label='Теоретична складність O(n^2)')
ax.legend()
ax.set_title("Dijkstra")
ax.set_xlabel("Edges")
ax.set_ylabel("Ticks")
# Out:
# Text(0, 0.5, 'Ticks')

# %%
fig, ax = plt.subplots() 
plt.grid()
sizes = [i for i in range(15,20*250,250)]
experimental =[1150030,215781,597839,1206531,2003626,3096722,4383779,5840648,7553638,9309678,10145647,11173553,13041381,15251303,18434446,20636016,23442813,25987819,29162008,31550584]
ax.plot(sizes,experimental,label='Реальна складність')
ax.plot(sizes,np.linspace(np.sqrt(110_0000),np.sqrt(32000000),20)**2,'--r',label='Теоретична складність O(n^2)')
ax.legend()
ax.set_title("Greedy Coloring")
ax.set_xlabel("Edges")
ax.set_ylabel("Ticks")
# Out:
# Text(0, 0.5, 'Ticks')
