# %%
import numpy as np
import pandas as pd
from IPython.display import Markdown as md
from IPython.display import display
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as tkr

# %%
def numfmt(x, pos): # your custom formatter function: divide by 100.0
    s = '{}k'.format(x / 1000.0)
    return s

fig, ax = plt.subplots() 
plt.grid()
ax.plot(np.square([100_0,200_0,300_0,400_0,500_0]),[8.142857142857142,32.714285714285715,73.71428571428571,131.28571428571428,208.57142857142858],label='Реальна складність')
ax.plot(np.square([100_0,500_0]),[10,205],'--r',label='Теоретична складність O(n*m)')
ax.legend()
# my_xticks = ['100k','200k','300k','400k','500k']
# plt.xticks([100_0,200_0,300_0,400_0,500_0], my_xticks)
ax.set_xlabel("Size")
ax.set_ylabel("Milliseconds")
# Out:
# Text(0, 0.5, 'Milliseconds')

# %%
fig, ax = plt.subplots() 
plt.grid()
ax.plot([100_0,200_0,300_0,400_0,500_0],[8.142857142857142,32.714285714285715,73.71428571428571,131.28571428571428,208.57142857142858],label='Реальна складність')
ax.plot(np.linspace(1000,5000,10),np.linspace(np.sqrt(10),np.sqrt(215),10)**2,'--r',label='Теоретична складність O(n^2)')
ax.legend()
# my_xticks = ['100k','200k','300k','400k','500k']
# plt.xticks([100_0,200_0,300_0,400_0,500_0], my_xticks)
ax.set_xlabel("Size")
ax.set_ylabel("Milliseconds")
# Out:
# Text(0, 0.5, 'Milliseconds')
